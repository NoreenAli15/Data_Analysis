# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("clean_dataset.csv")

# %%
df
# Out:
#      Gender    Age    Debt  Married  BankCustomer         Industry Ethnicity  \
# 0         1  30.83   0.000        1             1      Industrials     White
# 1         0  58.67   4.460        1             1        Materials     Black
# 2         0  24.50   0.500        1             1        Materials     Black
# 3         1  27.83   1.540        1             1      Industrials     White
# 4         1  20.17   5.625        1             1      Industrials     White
# ..      ...    ...     ...      ...           ...              ...       ...
# 685       1  21.08  10.085        0             0        Education     Black
# 686       0  22.67   0.750        1             1           Energy     White
# 687       0  25.25  13.500        0             0       Healthcare    Latino
# 688       1  17.92   0.205        1             1  ConsumerStaples     White
# 689       1  35.00   3.375        1             1           Energy     Black
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %%
#pie chart
mar=(df['Married']==1).sum()
notmar=(df['Married']==0).sum()
sizes=[mar,notmar]
labels=['Married','Not Married']
plt.pie(sizes,labels=labels,shadow=True,autopct='%1.1f%%')
plt.legend()
plt.figure(figsize=(66, 66))
plt.savefig('image')
plt.show()

# %%
#bar chart
import matplotlib.pyplot as plt

approved = (df['Approved'] == 1).sum()
notapproved = (df['Approved'] == 0).sum()

categories = ['Approved', 'Not Approved']
counts = [approved, notapproved]

plt.bar(categories, counts,color = "#4CAF50",width = .66)
plt.xlabel('Approval Status')
plt.ylabel('Count')
plt.title('Count of Approved vs Not Approved')
plt.grid()
plt.show()

# %%
#histogram
plt.hist(df['YearsEmployed'])
plt.show()

# %%
#boxplot
sns.boxplot(y="Age", x="Approved", hue='Approved',data=df,palette='viridis')
# Out:
# <AxesSubplot:xlabel='Approved', ylabel='Age'>

# %%
#violinplot
sns.violinplot(x="Married", y="Debt", data=df,hue='Married')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='Debt'>

# %%
#countblot
sns.countplot(x='Married',data=df,palette='rocket',hue='Married')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
#heatmap
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#distplot
sns.distplot(df['Age'],kde=True)
# Out:
# C:\Users\aa\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
#kdeplot
sns.kdeplot(df['Age'],shade=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
#pairplot
sns.pairplot(df)
